# %%
data <- read.table("https://archive.ics.uci.edu/ml/datasets/Bank+Marketing",header=False)
head(data)
# Out:
# Error in read.table("https://archive.ics.uci.edu/ml/datasets/Bank+Marketing", : 'False' nesnesi bulunamadı
# Traceback:
#
# 1. read.table("https://archive.ics.uci.edu/ml/datasets/Bank+Marketing",
#  .     header = False)

# %%
data <- read.table("https://archive.ics.uci.edu/ml/datasets/Bank+Marketing",header=F)
head(data)
# Out:
# Error in scan(file = file, what = what, sep = sep, quote = quote, dec = dec, : 1 . dize 8 öğeye sahip değil
# Traceback:
#
# 1. read.table("https://archive.ics.uci.edu/ml/datasets/Bank+Marketing",
#  .     header = F)
# 2. scan(file = file, what = what, sep = sep, quote = quote, dec = dec,
#  .     nmax = nrows, skip = 0, na.strings = na.strings, quiet = TRUE,
#  .     fill = fill, strip.white = strip.white, blank.lines.skip = blank.lines.skip,
#  .     multi.line = FALSE, comment.char = comment.char, allowEscapes = allowEscapes,
#  .     flush = flush, encoding = encoding, skipNul = skipNul)

# %%
data <- read.csv("https://archive.ics.uci.edu/ml/datasets/Bank+Marketing",header=F)
head(data)
# Out:
#   V1
# 1 <!DOCTYPE HTML PUBLIC \\-//W3C//DTD HTML 4.01 Transitional//EN\\>
# 2 <html>
# 3 <head>
# 4 <title>UCI Machine Learning Repository: Bank Marketing Data Set</title>
# 5 <!-- Stylesheet link -->
# 6 <link rel=stylesheet type=text/css href=../assets/ml.css />

# %%
getwd()
# Out:
# [1] "C:/Users/Elif"

# %%
path <- file.path("banka.txt")

# %%
path <- file.path("Banka.txt")
data <- read.table(path,header=T,row.names=1,sep="\t")
head(data)
# Out:
# Warning message in file(file, "rt"):
# "dosya 'Banka.txt' açılamadı: No such file or directory"
# Error in file(file, "rt"): bağlantı açılamadı
# Traceback:
#
# 1. read.table(path, header = T, row.names = 1, sep = "\t")
# 2. file(file, "rt")

# %%
setwd(C:/Users/Elif/Desktop)
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:9: beklenmeyen durum, '/'
# 1: setwd(C:/
#             ^
# Traceback:

# %%
setwd("C:/Users/Elif/Desktop")

# %%
getwd()
# Out:
# [1] "C:/Users/Elif/Desktop"

# %%
data <- read.table("Banka.txt",header=T,row.names=1,sep="\t")
head(data)
# Out:
# Error in read.table("Banka.txt", header = T, row.names = 1, sep = "\t"): duplicate 'row.names' are not allowed
# Traceback:
#
# 1. read.table("Banka.txt", header = T, row.names = 1, sep = "\t")
# 2. stop("duplicate 'row.names' are not allowed")

# %%
data <- read.table("Banka.txt",header=T,row.names=1,sep="\t")
print(data)
# Out:
# Error in read.table("Banka.txt", header = T, row.names = 1, sep = "\t"): duplicate 'row.names' are not allowed
# Traceback:
#
# 1. read.table("Banka.txt", header = T, row.names = 1, sep = "\t")
# 2. stop("duplicate 'row.names' are not allowed")

# %%
data <- read.table("Banka.txt",header=T,sep="\t")
head(data)
# Out:
#   age job         marital education default balance housing loan contact  day
# 1 30  unemployed  married primary   no      1787    no      no   cellular 19
# 2 33  services    married secondary no      4789    yes     yes  cellular 11
# 3 35  management  single  tertiary  no      1350    yes     no   cellular 16
# 4 30  management  married tertiary  no      1476    yes     yes  unknown   3
# 5 59  blue-collar married secondary no         0    yes     no   unknown   5
# 6 35  management  single  tertiary  no       747    no      no   cellular 23
#   month duration campaign pdays previous poutcome y
# 1 oct    79      1         -1   0        unknown  no
# 2 may   220      1        339   4        failure  no
# 3 apr   185      1        330   1        failure  no
# 4 jun   199      4         -1   0        unknown  no
# 5 may   226      1         -1   0        unknown  no
# 6 feb   141      2        176   3        failure  no

# %%
data <- read.table("Banka.txt",header=T,row.names=1,sep="\t")
print(data)
# Out:
# Error in read.table("Banka.txt", header = T, row.names = 1, sep = "\t"): duplicate 'row.names' are not allowed
# Traceback:
#
# 1. read.table("Banka.txt", header = T, row.names = 1, sep = "\t")
# 2. stop("duplicate 'row.names' are not allowed")

# %%
data <- read.table("Banka.txt",header=T,sep="\t")
print(data)
# Out:
#      age           job  marital education default balance housing loan
# 1     30    unemployed  married   primary      no    1787      no   no
# 2     33      services  married secondary      no    4789     yes  yes
# 3     35    management   single  tertiary      no    1350     yes   no
# 4     30    management  married  tertiary      no    1476     yes  yes
# 5     59   blue-collar  married secondary      no       0     yes   no
# 6     35    management   single  tertiary      no     747      no   no
# 7     36 self-employed  married  tertiary      no     307     yes   no
# 8     39    technician  married secondary      no     147     yes   no
# 9     41  entrepreneur  married  tertiary      no     221     yes   no
# 10    43      services  married   primary      no     -88     yes  yes
# 11    39      services  married secondary      no    9374     yes   no
# 12    43        admin.  married secondary      no     264     yes   no
# ...

# %%
data <- read.table("banka.txt",header=T,sep="\t")

# %%
head(data)
# Out:
#   age job         marital education default balance housing loan contact  day
# 1 30  unemployed  married primary   no      1787    no      no   cellular 19
# 2 33  services    married secondary no      4789    yes     yes  cellular 11
# 3 35  management  single  tertiary  no      1350    yes     no   cellular 16
# 4 30  management  married tertiary  no      1476    yes     yes  unknown   3
# 5 59  blue-collar married secondary no         0    yes     no   unknown   5
# 6 35  management  single  tertiary  no       747    no      no   cellular 23
#   month duration campaign pdays previous poutcome y
# 1 oct    79      1         -1   0        unknown  no
# 2 may   220      1        339   4        failure  no
# 3 apr   185      1        330   1        failure  no
# 4 jun   199      4         -1   0        unknown  no
# 5 may   226      1         -1   0        unknown  no
# 6 feb   141      2        176   3        failure  no
